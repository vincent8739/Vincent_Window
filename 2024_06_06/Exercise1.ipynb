# %%
li1 = [3, 15, 7, 9, 25]
li1.sort(reverse=True)
li1
# Out:
# [25, 15, 9, 7, 3]

# %%
li2 = [3, 15, 7, 9, 25]
new_li2 = sorted(li2)
new_li2
# Out:
# [3, 7, 9, 15, 25]

# %%
#lambda ->匿名的function
people = [
    {"name": "John", "age": 30},
    {"name": "Jane", "age": 25},
    {"name": "Dave", "age": 35}
]

def sort_key(value:dict)->int:
    return value["age"]
new_people=sorted(people,key=lambda value:value["age"],reverse=True)
new_people
# Out:
# [{'name': 'Dave', 'age': 35},
#  {'name': 'John', 'age': 30},
#  {'name': 'Jane', 'age': 25}]

# %%
#使用map()
def square(x):
    return f'我是第{x}元素'
numbers = [1, 2, 3, 4, 5]
str_list:list[str] = list(map(square,numbers))
# "\n".join(str_list)
print("\n".join(str_list))
# Out:
# 我是第1元素
# 我是第2元素
# 我是第3元素
# 我是第4元素
# 我是第5元素

# %%
import tkinter as tk

def calculate_bmi():
    height = float(height_entry.get())
    weight = float(weight_entry.get())
    
    # 先將身高轉換為公尺
    height_m = height / 100
    
    # 計算BMI
    bmi = weight / (height_m ** 2)
    
    result_label.config(text="您的BMI為 {:.2f}".format(bmi))

# 建立主視窗
root = tk.Tk()
root.title("BMI 計算器")

# 身高輸入
height_label = tk.Label(root, text="請輸入您的身高（公分）：")
height_label.pack()
height_entry = tk.Entry(root)
height_entry.pack()

# 體重輸入
weight_label = tk.Label(root, text="請輸入您的體重（公斤）：")
weight_label.pack()
weight_entry = tk.Entry(root)
weight_entry.pack()

# 計算BMI按鈕
calculate_button = tk.Button(root, text="計算BMI", command=calculate_bmi)
calculate_button.pack()

# 顯示結果
result_label = tk.Label(root, text="")
result_label.pack()

# 啟動主迴圈
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk

def calculate_bmi():
    name = name_entry.get()
    height = float(height_entry.get())
    weight = float(weight_entry.get())
    
    # 先將身高轉換為公尺
    height_m = height / 100
    
    # 計算BMI
    bmi = weight / (height_m ** 2)
    
    result_label.config(text="{} 先生/小姐的BMI為 {:.2f}".format(name, bmi))

# 建立主視窗
root = tk.Tk()
root.title("BMI 計算器")
root.geometry("300x250")

# 設定字型
font_style = ("Arial", 12)

# 姓名輸入
name_label = ttk.Label(root, text="請輸入您的姓名：", font=font_style)
name_label.pack(pady=5)
name_entry = ttk.Entry(root, font=font_style)
name_entry.pack(pady=5)

# 身高輸入
height_label = ttk.Label(root, text="請輸入您的身高（公分）：", font=font_style)
height_label.pack(pady=5)
height_entry = ttk.Entry(root, font=font_style)
height_entry.pack(pady=5)

# 體重輸入
weight_label = ttk.Label(root, text="請輸入您的體重（公斤）：", font=font_style)
weight_label.pack(pady=5)
weight_entry = ttk.Entry(root, font=font_style)
weight_entry.pack(pady=5)

# 計算BMI按鈕
calculate_button = ttk.Button(root, text="計算BMI", command=calculate_bmi, style="TButton")
calculate_button.pack(pady=10)

# 顯示結果
result_label = ttk.Label(root, text="", font=font_style)
result_label.pack()

# 設定按鈕風格
style = ttk.Style()
style.configure("TButton", font=font_style)

# 啟動主迴圈
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk

def calculate_bmi():
    name = name_entry.get()
    height = float(height_entry.get())
    weight = float(weight_entry.get())
    
    # 先將身高轉換為公尺
    height_m = height / 100
    
    # 計算BMI
    bmi = weight / (height_m ** 2)
    
    result_label.config(text="{} 先生/小姐的BMI為 {:.2f}".format(name, bmi))
    
    # 判斷BMI是否超出標準範圍，並給出建議體重
    if bmi < 18.5:
        advice = "您的體重過輕，建議增加體重。"
    elif bmi >= 18.5 and bmi < 24:
        advice = "您的體重屬於正常範圍。"
    elif bmi >= 24 and bmi < 27:
        advice = "您的體重過重，建議減輕體重。"
    elif bmi >= 27 and bmi < 30:
        advice = "您的體重輕度肥胖，建議減輕體重。"
    elif bmi >= 30 and bmi < 35:
        advice = "您的體重中度肥胖，建議減輕體重。"
    else:
        advice = "您的體重重度肥胖，建議尋求專業幫助。"
    
    advice_label.config(text=advice)

# 建立主視窗
root = tk.Tk()
root.title("BMI 計算器")
root.geometry("300x300")

# 設定字型
font_style = ("Arial", 12)

# 姓名輸入
name_label = ttk.Label(root, text="請輸入您的姓名：", font=font_style)
name_label.pack(pady=5)
name_entry = ttk.Entry(root, font=font_style)
name_entry.pack(pady=5)

# 身高輸入
height_label = ttk.Label(root, text="請輸入您的身高（公分）：", font=font_style)
height_label.pack(pady=5)
height_entry = ttk.Entry(root, font=font_style)
height_entry.pack(pady=5)

# 體重輸入
weight_label = ttk.Label(root, text="請輸入您的體重（公斤）：", font=font_style)
weight_label.pack(pady=5)
weight_entry = ttk.Entry(root, font=font_style)
weight_entry.pack(pady=5)

# 計算BMI按鈕
calculate_button = ttk.Button(root, text="計算BMI", command=calculate_bmi, style="TButton")
calculate_button.pack(pady=10)

# 顯示結果
result_label = ttk.Label(root, text="", font=font_style)
result_label.pack()

# 顯示建議
advice_label = ttk.Label(root, text="", font=font_style)
advice_label.pack()

# 設定按鈕風格
style = ttk.Style()
style.configure("TButton", font=font_style)

# 啟動主迴圈
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk

def calculate_bmi():
    name = name_entry.get()
    height = float(height_entry.get())
    weight = float(weight_entry.get())
    
    # 先將身高轉換為公尺
    height_m = height / 100
    
    # 計算BMI
    bmi = weight / (height_m ** 2)
    
    result_label.config(text="{} 先生/小姐的BMI為 {:.2f}".format(name, bmi))
    
    # 判斷BMI是否超出標準範圍，並給出建議體重
    if bmi < 18.5:
        advice = "您的體重過輕，建議增加體重。"
    elif bmi >= 18.5 and bmi < 24:
        advice = "您的體重屬於正常範圍。"
    elif bmi >= 24 and bmi < 27:
        advice = "您的體重過重，建議減輕體重。"
    elif bmi >= 27 and bmi < 30:
        advice = "您的體重輕度肥胖，建議減輕體重。"
    elif bmi >= 30 and bmi < 35:
        advice = "您的體重中度肥胖，建議減輕體重。"
    else:
        advice = "您的體重重度肥胖，建議尋求專業幫助。"
    
    advice_label.config(text=advice)

# 建立主視窗
root = tk.Tk()
root.title("BMI 計算器")
root.geometry("300x300")

# 設定字型
font_style = ("Arial", 12)

# 姓名輸入
name_label = ttk.Label(root, text="請輸入您的姓名：", font=font_style)
name_label.pack(pady=5)
name_entry = ttk.Entry(root, font=font_style)
name_entry.pack(pady=5)

# 身高輸入
height_label = ttk.Label(root, text="請輸入您的身高（公分）：", font=font_style)
height_label.pack(pady=5)
height_entry = ttk.Entry(root, font=font_style)
height_entry.pack(pady=5)

# 體重輸入
weight_label = ttk.Label(root, text="請輸入您的體重（公斤）：", font=font_style)
weight_label.pack(pady=5)
weight_entry = ttk.Entry(root, font=font_style)
weight_entry.pack(pady=5)

# 計算BMI按鈕
calculate_button = ttk.Button(root, text="計算BMI", command=calculate_bmi, style="TButton")
calculate_button.pack(pady=10)

# 顯示結果
result_label = ttk.Label(root, text="", font=font_style)
result_label.pack()

# 顯示建議
advice_label = ttk.Label(root, text="", font=font_style)
advice_label.pack()

# 設定按鈕風格
style = ttk.Style()
style.configure("TButton", font=font_style)

# 啟動主迴圈
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk

def calculate_bmi():
    name = name_entry.get()
    height = float(height_entry.get())
    weight = float(weight_entry.get())
    
    # 先將身高轉換為公尺
    height_m = height / 100
    
    # 計算BMI
    bmi = weight / (height_m ** 2)
    
    result_label.config(text="{} 先生/小姐的BMI為 {:.2f}".format(name, bmi))
    
    # 判斷BMI是否超出標準範圍，並給出建議體重
    if bmi < 18.5:
        advice = "您的體重過輕，建議增加體重。"
    elif bmi >= 18.5 and bmi < 24:
        advice = "您的體重屬於正常範圍。"
    elif bmi >= 24 and bmi < 27:
        advice = "您的體重過重，建議減輕體重。"
    elif bmi >= 27 and bmi < 30:
        advice = "您的體重輕度肥胖，建議減輕體重。"
    elif bmi >= 30 and bmi < 35:
        advice = "您的體重中度肥胖，建議減輕體重。"
    else:
        advice = "您的體重重度肥胖，建議尋求專業幫助。"
    
    standard_bmi_label.config(text="標準BMI值範圍：過輕 < 18.5, 正常 18.5 - 24, 過重 24 - 27, 輕度肥胖 27 - 30, 中度肥胖 30 - 35, 重度肥胖 > 35")
    advice_label.config(text=advice)

# 建立主視窗
root = tk.Tk()
root.title("BMI 計算器")
root.geometry("400x350")

# 設定字型
font_style = ("Arial", 12)

# 姓名輸入
name_label = ttk.Label(root, text="請輸入您的姓名：", font=font_style)
name_label.pack(pady=5)
name_entry = ttk.Entry(root, font=font_style)
name_entry.pack(pady=5)

# 身高輸入
height_label = ttk.Label(root, text="請輸入您的身高（公分）：", font=font_style)
height_label.pack(pady=5)
height_entry = ttk.Entry(root, font=font_style)
height_entry.pack(pady=5)

# 體重輸入
weight_label = ttk.Label(root, text="請輸入您的體重（公斤）：", font=font_style)
weight_label.pack(pady=5)
weight_entry = ttk.Entry(root, font=font_style)
weight_entry.pack(pady=5)

# 計算BMI按鈕
calculate_button = ttk.Button(root, text="計算BMI", command=calculate_bmi, style="TButton")
calculate_button.pack(pady=10)

# 顯示結果
result_label = ttk.Label(root, text="", font=font_style)
result_label.pack()

# 顯示標準BMI值範圍
standard_bmi_label = ttk.Label(root, text="", font=font_style)
standard_bmi_label.pack()

# 顯示建議
advice_label = ttk.Label(root, text="", font=font_style)
advice_label.pack()

# 設定按鈕風格
style = ttk.Style()
style.configure("TButton", font=font_style)

# 啟動主迴圈
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk

def calculate_bmi():
    name = name_entry.get()
    height = float(height_entry.get())
    weight = float(weight_entry.get())
    
    # 先將身高轉換為公尺
    height_m = height / 100
    
    # 計算BMI
    bmi = weight / (height_m ** 2)
    
    result_label.config(text="{} 先生/小姐的BMI為 {:.2f}".format(name, bmi))
    
    # 判斷BMI是否超出標準範圍，並給出建議體重
    if bmi < 18.5:
        advice = "您的體重過輕，建議增加體重。"
    elif bmi >= 18.5 and bmi < 24:
        advice = "您的體重屬於正常範圍。"
    elif bmi >= 24 and bmi < 27:
        advice = "您的體重過重，建議減輕體重。"
    elif bmi >= 27 and bmi < 30:
        advice = "您的體重輕度肥胖，建議減輕體重。"
    elif bmi >= 30 and bmi < 35:
        advice = "您的體重中度肥胖，建議減輕體重。"
    else:
        advice = "您的體重重度肥胖，建議尋求專業幫助。"
    
    # 根據BMI值計算標準體重
    standard_weight_lower = 18.5 * (height_m ** 2)
    standard_weight_upper = 24 * (height_m ** 2)
    
    standard_weight_range = "標準體重範圍：{:.1f} 公斤 - {:.1f} 公斤".format(standard_weight_lower, standard_weight_upper)
    standard_weight_label.config(text=standard_weight_range)
    
    # 計算實際體重與標準體重之間的差
    weight_difference_lower = weight - standard_weight_lower
    weight_difference_upper = weight - standard_weight_upper
    
    weight_difference = "體重與標準體重差距：{:.1f} 公斤 - {:.1f} 公斤".format(weight_difference_lower, weight_difference_upper)
    weight_difference_label.config(text=weight_difference)
    
    advice_label.config(text=advice)

# 建立主視窗
root = tk.Tk()
root.title("BMI 計算器")
root.geometry("400x350")

# 設定字型
font_style = ("Arial", 12)

# 姓名輸入
name_label = ttk.Label(root, text="請輸入您的姓名：", font=font_style)
name_label.pack(pady=5)
name_entry = ttk.Entry(root, font=font_style)
name_entry.pack(pady=5)

# 身高輸入
height_label = ttk.Label(root, text="請輸入您的身高（公分）：", font=font_style)
height_label.pack(pady=5)
height_entry = ttk.Entry(root, font=font_style)
height_entry.pack(pady=5)

# 體重輸入
weight_label = ttk.Label(root, text="請輸入您的體重（公斤）：", font=font_style)
weight_label.pack(pady=5)
weight_entry = ttk.Entry(root, font=font_style)
weight_entry.pack(pady=5)

# 計算BMI按鈕
calculate_button = ttk.Button(root, text="計算BMI", command=calculate_bmi, style="TButton")
calculate_button.pack(pady=10)

# 顯示結果
result_label = ttk.Label(root, text="", font=font_style)
result_label.pack()

# 顯示標準體重範圍
standard_weight_label = ttk.Label(root, text="", font=font_style)
standard_weight_label.pack()

# 顯示實際體重與標準體重差
weight_difference_label = ttk.Label(root, text="", font=font_style)
weight_difference_label.pack()

# 顯示建議
advice_label = ttk.Label(root, text="", font=font_style)
advice_label.pack()

# 設定按鈕風格
style = ttk.Style()
style.configure("TButton", font=font_style)

# 啟動主迴圈
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk

def calculate_bmi():
    name = name_entry.get()
    height = float(height_entry.get())
    weight = float(weight_entry.get())
    
    # 先將身高轉換為公尺
    height_m = height / 100
    
    # 計算BMI
    bmi = weight / (height_m ** 2)
    
    result_label.config(text="{} 先生/小姐的BMI為 {:.2f}".format(name, bmi))
    
    # 判斷BMI是否超出標準範圍，並給出建議體重
    if bmi < 18.5:
        advice = "您的體重過輕，建議增加體重。"
    elif bmi >= 18.5 and bmi < 24:
        advice = "您的體重屬於正常範圍。"
    elif bmi >= 24 and bmi < 27:
        advice = "您的體重過重，建議減輕體重。"
    elif bmi >= 27 and bmi < 30:
        advice = "您的體重輕度肥胖，建議減輕體重。"
    elif bmi >= 30 and bmi < 35:
        advice = "您的體重中度肥胖，建議減輕體重。"
    else:
        advice = "您的體重重度肥胖，建議尋求專業幫助。"
    
    # 根據BMI值計算標準體重
    standard_weight_lower = 18.5 * (height_m ** 2)
    standard_weight_upper = 24 * (height_m ** 2)
    
    standard_weight_range = "標準體重範圍：{:.1f} 公斤 - {:.1f} 公斤".format(standard_weight_lower, standard_weight_upper)
    standard_weight_label.config(text=standard_weight_range)
    
    # 計算實際體重與標準體重之間的差
    weight_difference_lower = weight - standard_weight_lower
    weight_difference_upper = weight - standard_weight_upper
    
    weight_difference = "體重與標準體重差距：{:.1f} 公斤 - {:.1f} 公斤".format(weight_difference_lower, weight_difference_upper)
    weight_difference_label.config(text=weight_difference)
    
    advice_label.config(text=advice)

# 建立主視窗
root = tk.Tk()
root.title("BMI 計算器")

# 姓名輸入
name_label = ttk.Label(root, text="請輸入您的姓名：")
name_label.grid(row=0, column=0, pady=5)
name_entry = ttk.Entry(root)
name_entry.grid(row=0, column=1, pady=5)

# 身高輸入
height_label = ttk.Label(root, text="請輸入您的身高（公分）：")
height_label.grid(row=1, column=0, pady=5)
height_entry = ttk.Entry(root)
height_entry.grid(row=1, column=1, pady=5)

# 體重輸入
weight_label = ttk.Label(root, text="請輸入您的體重（公斤）：")
weight_label.grid(row=2, column=0, pady=5)
weight_entry = ttk.Entry(root)
weight_entry.grid(row=2, column=1, pady=5)

# 計算BMI按鈕
calculate_button = ttk.Button(root, text="計算BMI", command=calculate_bmi)
calculate_button.grid(row=3, column=0, columnspan=2, pady=10)

# 顯示結果
result_label = ttk.Label(root, text="")
result_label.grid(row=4, column=0, columnspan=2)

# 顯示標準體重範圍
standard_weight_label = ttk.Label(root, text="")
standard_weight_label.grid(row=5, column=0, columnspan=2)

# 顯示體重與標準體重差距
weight_difference_label = ttk.Label(root, text="")
weight_difference_label.grid(row=6, column=0, columnspan=2)

# 顯示建議
advice_label = ttk.Label(root, text="")
advice_label.grid(row=7, column=0, columnspan=2)

# 啟動主迴圈
root.mainloop()
